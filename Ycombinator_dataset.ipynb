# %% [markdown]
# <a href="https://colab.research.google.com/github/altosaxis/ultrabooker/blob/main/Ycombinator_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1323 = pd.read_csv('yc1323.csv')

# %%
df1323.head()
# Out:
#    company_id      company_name  \
# 0       28415          moonrepo
# 1       28412       SpeedyBrand
# 2       28409           BerriAI
# 3       28425  Pando Bioscience
# 4       28413         SpecCheck
#
#                                    short_description  \
# 0  Open source build tool for monorepos and large...
# 1   Generative-AI powered Marketing Content for SMBs
# 2             Stop OpenAI Errors w/ 1 line of code 👈
# 3   Decipher complex diseases using protein networks
# 4   Unifying how the optical industry does business.
#
#                                     long_description batch  status  \
# 0  moonrepo is a developer tool that reduces buil...   W23  Active
# 1  SpeedyBrand provides SMBs with generative-AI p...   W23  Active
# 2  Stop OpenAI Errors in 1 line of code\r\n\r\n``...   W23  Active
# 3  Pando Bioscience is a Boston-based synthetic b...   W23  Active
# 4  SpecCheck is an all-in-one solution that provi...   W23  Active
#
# ...

# %%
df2723 = pd.read_csv('yc2723.csv')

# %%
df2723.head()
# Out:
#    company_id      company_name  \
# 0       28425  Pando Bioscience
# 1       28421      Apollo Group
# 2       28416            Pierre
# 3       28415          moonrepo
# 4       28414             Lasso
#
#                                    short_description  \
# 0   Decipher complex diseases using protein networks
# 1  A marketplace for consumers to hire trained bl...
# 2                           A new way to review code
# 3  A developer productivity platform for managing...
# 4  robotic process automation for chrome using GP...
#
#                                     long_description batch  status  \
# 0  Pando Bioscience is a Boston-based synthetic b...   W23  Active
# 1  Apollo Group is a diversified technology group...   W23  Active
# 2  Pierre enables engineers, designers and busine...   W23  Active
# 3  moonrepo is a developer tool that reduces buil...   W23  Active
# 4  🧐 The problem: Traditional Robotic Process Aut...   W23  Active
#
# ...

# %%
df1124 = pd.read_csv('yc1124.csv')

# %%
df1124.head()
# Out:
#    company_id   company_name  \
# 0       29523   K-Scale Labs
# 1       29519  Forge Rewards
# 2       29517    RetailReady
# 3       29610     Hamming AI
# 4       29518        FanCave
#
#                                    short_description  \
# 0                        Open-source humanoid robots
# 1  All-in-one operations software to power restau...
# 2       An AI-powered supply chain compliance engine
# 3                                 Making AI reliable
# 4         Powering the free agency of college sports
#
#                                     long_description batch  status  \
# 0  We're building humanoid robots to do most of w...   W24  Active
# 1  Forge is the modern operations software for em...   W24  Active
# 2  Every time workers in a warehouse box an order...   W24  Active
# 3  If 2023 was the year of AI POCs, 2024 is the y...   S24  Active
# 4  FanCave powers the free agency of college spor...   W24  Active
#
# ...

# %%
print(f"{df1323.columns}\n{df2723.columns}\n{df1124.columns}")
# Out:
# Index(['company_id', 'company_name', 'short_description', 'long_description',
#        'batch', 'status', 'tags', 'location', 'country', 'year_founded',
#        'num_founders', 'founders_names', 'team_size', 'website', 'cb_url',
#        'linkedin_url'],
#       dtype='object')
# Index(['company_id', 'company_name', 'short_description', 'long_description',
#        'batch', 'status', 'tags', 'location', 'country', 'year_founded',
#        'num_founders', 'founders_names', 'team_size', 'website', 'cb_url',
#        'linkedin_url'],
#       dtype='object')
# Index(['company_id', 'company_name', 'short_description', 'long_description',
#        'batch', 'status', 'tags', 'location', 'country', 'year_founded',
#        'num_founders', 'founders_names', 'team_size', 'website', 'cb_url',
#        'linkedin_url'],
#       dtype='object')

# %%
print(f"{df1323.size} {df2723.size} {df1124.size}")
# Out:
# 134560 66048 74608

# %%
df1323.company_id.nunique(), df2723.company_id.nunique(), df1124.company_id.nunique()
# Out:
# (4297, 4128, 4663)

# %%
df1323.company_name.nunique(), df2723.company_name.nunique(), df1124.company_name.nunique()
# Out:
# (4248, 4082, 4604)

# %%
df1323['tags'].unique()
# Out:
# array(["['Developer Tools', 'SaaS', 'Productivity', 'Open Source', 'Enterprise']",
#        '[]',
#        "['Artificial Intelligence', 'Developer Tools', 'Generative AI']",
#        ..., "['Energy Storage', 'Electric Vehicles']",
#        "['Media', 'Careers']",
#        "['Marketplace', 'Collaboration', 'Marketing', 'Retail Tech', 'Retail']"],
#       dtype=object)

# %%
df2723['tags'].unique()
# Out:
# array(["['Drug discovery', 'Biotech', 'Diagnostics', 'Synthetic Biology']",
#        "['Home Services', 'International', 'Marketplace', 'Consumer']",
#        "['Developer Tools', 'Collaboration', 'AI-Enhanced Learning', 'B2B', 'Productivity']",
#        ..., "['Social', 'Gaming']",
#        "['Music', 'Social Network', 'Collaboration']",
#        "['Community', 'Social', 'Social Media', 'Social Network']"],
#       dtype=object)

# %%
df1124['tags'].unique()
# Out:
# array(["['artificial-intelligence', 'machine-learning', 'robotics', 'consumer']",
#        "['fintech', 'food-tech', 'ai']",
#        "['b2b', 'compliance', 'logistics', 'supply-chain', 'ai']", ...,
#        "['ai-enhanced-learning', 'remote-work', 'edtech']",
#        "['collaboration', 'social-network', 'music']",
#        "['community', 'social-media', 'social', 'social-network']"],
#       dtype=object)

# %%
df1323["Quantum" in df1323['short_description']] ## will not work try np.where
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3790         try:
# -> 3791             return self._engine.get_loc(casted_key)
#    3792         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-2dd8f8e46754> in <cell line: 1>()
# ...

# %%
df1323[df1323['short_description'].str.contains('Quantum', case = "False")]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-aea8609bd1f5> in <cell line: 1>()
# ----> 1 df1323[df1323['short_description'].str.contains('Quantum', case = "False")]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3881
#    3882         # Do we have a (boolean) 1d indexer?
# -> 3883         if com.is_bool_indexer(key):
#    3884             return self._getitem_bool_array(key)
#    3885
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/common.py in is_bool_indexer(key)
#     131                     # Don't raise on e.g. ["A", "B", np.nan], see
#     132                     #  test_loc_getitem_list_of_labels_categoricalindex_with_na
# --> 133                     raise ValueError(na_msg)
#     134                 return False
#     135             return True
#
# ...

# %%
df1323.short_description.isna().sum()
# Out:
# 385

# %%
df1323.short_description.dropna()
# Out:
# 0       Open source build tool for monorepos and large...
# 1        Generative-AI powered Marketing Content for SMBs
# 2                  Stop OpenAI Errors w/ 1 line of code 👈
# 3        Decipher complex diseases using protein networks
# 4        Unifying how the optical industry does business.
#                               ...
# 8390                                        Online polls.
# 8393                                 Online form builder.
# 8401                       The frontpage of the internet.
# 8402                    We sold Snipshot to Ansa in 2013.
# 8403    We're the best online calendar solution to eve...
# Name: short_description, Length: 8025, dtype: object

# %%
df1323.short_description.isna().sum()
# Out:
# 385

# %%
df1323["short_description"] = df1323["short_description"].fillna('None')

# %%
df1323.short_description.isna().sum()
# Out:
# 0

# %%
df1323.dtypes
# Out:
# company_id             int64
# company_name          object
# short_description     object
# long_description      object
# batch                 object
# status                object
# tags                  object
# location              object
# country               object
# year_founded         float64
# num_founders           int64
# founders_names        object
# team_size            float64
# website               object
# cb_url                object
# linkedin_url          object
# dtype: object

# %%
df1323['short_description'] = df1323['short_description'].astype('str')

# %%
df1323.dtypes
# Out:
# company_id             int64
# company_name          object
# short_description     object
# long_description      object
# batch                 object
# status                object
# tags                  object
# location              object
# country               object
# year_founded         float64
# num_founders           int64
# founders_names        object
# team_size            float64
# website               object
# cb_url                object
# linkedin_url          object
# dtype: object

# %%
df1323['short_description'][df1323['short_description'].str.contains("Quantum", case=False)]
# Out:
# 1789    Menten AI designs peptide and protein therapeu...
# 2265    Building the first practical, integrated quant...
# 3405                     Quantum coherent supercomputing.
# 6085    Menten AI designs peptide and protein therapeu...
# 6561    Building the first practical, integrated quant...
# 7702                     Quantum coherent supercomputing.
# Name: short_description, dtype: object

# %%
df1323['short_description'][df1323['short_description'].str.contains("Quantum", case=False)].str.wrap(800).values
# Out:
# array(['Menten AI designs peptide and protein therapeutics using quantum…',
#        'Building the first practical, integrated quantum computer.',
#        'Quantum coherent supercomputing.',
#        'Menten AI designs peptide and protein therapeutics using quantum…',
#        'Building the first practical, integrated quantum computer.',
#        'Quantum coherent supercomputing.'], dtype=object)

# %%
df1323[df1323['short_description'].str.contains("Quantum", case=False)]
# Out:
#       company_id       company_name  \
# 1789       13616          Menten AI
# 2265       12047            AuroraQ
# 3405         700  Rigetti Computing
# 6085       13616          Menten AI
# 6561       12047            AuroraQ
# 7702         700  Rigetti Computing
#
#                                       short_description  \
# 1789  Menten AI designs peptide and protein therapeu...
# 2265  Building the first practical, integrated quant...
# 3405                   Quantum coherent supercomputing.
# 6085  Menten AI designs peptide and protein therapeu...
# 6561  Building the first practical, integrated quant...
# 7702                   Quantum coherent supercomputing.
#
#                                        long_description batch  status  \
# 1789  Menten AI designs protein drugs and enzymes us...   W20  Active
# 2265  At AuroraQ, we are building the world’s first ...   W19  Active
# 3405  Rigetti Computing is building the world’s most...   S14  Public
# ...

# %%
df1323["short_description"][df1323['short_description'].str.contains("Blockchain", case=False)].str.wrap(800).values
# Out:
# array(['Blockchain infrastructure for Web3 games',
#        'The protocol for derivatives on blockchains',
#        'Stackup is a platform for building user-friendly blockchain products',
#        'Bringing physical collectibles to the blockchain.',
#        'Reliable blockchain indexing & querying for web3 engineering teams.',
#        'Tools & infra to build and scale high-quality blockchain applications.',
#        'Blockchain search engine',
#        'Open-source, design centric software for interacting with blockchains',
#        'Meson is a stablecoin swap protocol among blockchains and Layer 2s',
#        'Blockchain infrastructure for Web3 games',
#        'The protocol for derivatives on blockchains',
#        'Stackup is a platform for building user-friendly blockchain products',
#        'Bringing physical collectibles to the blockchain.',
#        'Reliable blockchain indexing & querying for web3 engineering teams.',
# ...

# %%
df1323[df1323['short_description'].str.contains("Blockchain", case=False)]
# Out:
#       company_id company_name  \
# 338        26818       Metafi
# 378        26743       EthosX
# 408        26705      Stackup
# 583        25787    Courtyard
# 865        24866      Satsuma
# 1231       22995    QuickNode
# 1894       13185     Operator
# 2017       12647      Rainbow
# 2637        1799        Meson
# 4620       26818       Metafi
# 4659       26743       EthosX
# 4691       26705      Stackup
# 4867       25787    Courtyard
# 5153       24866      Satsuma
# 5522       22995    QuickNode
# 6184       13185     Operator
# 6310       12647      Rainbow
# 6933        1799        Meson
#
#                                       short_description  \
# 338            Blockchain infrastructure for Web3 games
# 378         The protocol for derivatives on blockchains
# 408   Stackup is a platform for building user-friend...
# 583   Bringing physical collectibles to the blockcha...
# 865   Reliable blockchain indexing & querying for we...
# ...

# %%
df2723.long_description.isna().sum()
# Out:
# 331

# %%
df2723["long_description"] = df2723.long_description.fillna('none')

# %%
df2723.long_description.isna().sum()
# Out:
# 0

# %%
df2723["long_description"] = df2723.long_description.astype('str')

# %%
df2723["long_description"].isna().sum()
# Out:
# 0

# %%
df2723['long_description'][df2723['long_description'].str.contains("Quantum", case=False)].str.wrap(1800).values
# Out:
# array(['Menten AI designs protein drugs and enzymes using quantum computing and machine learning. Their technology leapfrogs current computational methods making it possible to design previously intractable proteins. The team created the first protein design algorithm for current and near-term quantum computers and created the world’s first protein designed on a quantum computer. They are now working on 3 new proteins, including a peptide to prevent the spread of viruses like Covid-19. They have 2 paid pilot projects with multinational chemical companies and 4 LOI’s with pharma and biotech companies.',
# ...

# %%
df2723['long_description'][df2723['long_description'].str.contains("Quantum", case=False)]
# Out:
# 1797    Menten AI designs protein drugs and enzymes us...
# 2273    At AuroraQ, we are building the world’s first ...
# 2761    Gamelynx is creating easily watchable cross-pl...
# 3419    Rigetti Computing is building the world’s most...
# Name: long_description, dtype: object

# %%
df2723['long_description'].str.contains("Quantum", case=False)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4123    False
# 4124    False
# 4125    False
# 4126    False
# 4127    False
# Name: long_description, Length: 4128, dtype: bool

# %%
df2723[df2723['long_description'].str.contains("Quantum", case=False)]
# Out:
#       company_id       company_name  \
# 1797       13616          Menten AI
# 2273       12047            AuroraQ
# 2761        1681           Gamelynx
# 3419         700  Rigetti Computing
#
#                                       short_description  \
# 1797  Menten AI designs peptide and protein therapeu...
# 2273  Building the first practical, integrated quant...
# 2761  Easily watchable cross-platform competitive ga...
# 3419                   Quantum coherent supercomputing.
#
#                                        long_description batch    status  \
# 1797  Menten AI designs protein drugs and enzymes us...   W20    Active
# 2273  At AuroraQ, we are building the world’s first ...   W19    Active
# 2761  Gamelynx is creating easily watchable cross-pl...   S17  Inactive
# 3419  Rigetti Computing is building the world’s most...   S14    Public
#
#                                                    tags          location  \
# ...

# %%
df1124.long_description.isna().sum()
# Out:
# 330

# %%
df1124["long_description"] = df1124.long_description.fillna('none')

# %%
df1124.long_description.isna().sum()
# Out:
# 0

# %%
df1124['long_description'][df1124['long_description'].str.contains("Quantum", case=False)].str.wrap(1800).values
# Out:
# array(['Deasie is a data governance layer to support safe & reliable use of language models in the enterprise. Our product connects to thousands of documents, auto-tags everything in terms of contents & sensitivity, and ensures that AI models are only ever fed with data that is relevant, safe & high-quality.    Our three founders (from Amazon, McKinsey/QuantumBlack & MIT) previously built an ML data governance tool from 0 to 1 within McKinsey, which we deployed with 11 Fortune 500 companies. We saw in early 2023 that the single greatest blocker to reliable and scalable adoption of GenAI, was the inability for enterprises to identify the right set of documents that should be used for a given application.     Our investors include General Catalyst, Y Combinator, RTP Global and world experts in enterprise data. Website: https://deasie.com',
# ...
